# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.get_account_summary()
# Out:
# {'id': '101-001-20947775-001',
#  'alias': 'Primary',
#  'currency': 'USD',
#  'balance': '100000.0',
#  'createdByUserID': 20947775,
#  'createdTime': '2021-11-02T19:36:53.639984823Z',
#  'guaranteedStopLossOrderMode': 'DISABLED',
#  'pl': '0.0',
#  'resettablePL': '0.0',
#  'resettablePLTime': '0',
#  'financing': '0.0',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.02',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '100000.0',
#  'marginUsed': '0.0',
#  'marginAvailable': '100000.0',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '100000.0',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '100000.0',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '3'}

# %%
api.account_type
# Out:
# 'practice'

# %%
api.account_type
# Out:
# 'practice'

# %%
api.get_instruments()
# Out:
# [('EUR/HUF', 'EUR_HUF'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('USD/MXN', 'USD_MXN'),
#  ('GBP/USD', 'GBP_USD'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('USD/THB', 'USD_THB'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('USD/SEK', 'USD_SEK'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('USD/CHF', 'USD_CHF'),
#  ('USD/TRY', 'USD_TRY'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('USD/JPY', 'USD_JPY'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('USD/CZK', 'USD_CZK'),
#  ('ZAR/JPY', 'ZAR_JPY'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('USD/DKK', 'USD_DKK'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('AUD/CAD', 'AUD_CAD'),
#  ('USD/HKD', 'USD_HKD'),
#  ('CAD/SGD', 'CAD_SGD'),
# ...

# %%
instr = api.get_instruments()

# %%
len(instr)
# Out:
# 68

# %%
instr[0]
# Out:
# ('EUR/HUF', 'EUR_HUF')

# %%
help(api.get_history)
# Out:
# Help on method get_history in module tpqoa.tpqoa:
#
# get_history(instrument, start, end, granularity, price) method of tpqoa.tpqoa.tpqoa instance
#     Retrieves historical data for instrument.
#
#     Parameters
# ...
#     instrument: string
#         valid instrument name
#     start, end: datetime, str
#         Python datetime or string objects for start and end
#     granularity: string
#         a string like 'S5', 'M1' or 'D'
#     price: string
#         one of 'A' (ask) or 'B' (bid)
#
#     Returns
# ...
#     data: pd.DataFrame
#         pandas DataFrame object with data

# %%
api.get_history(instrument= "EUR_USD", start = "2020-07-01", end = "2020-07-31", granularity= "D", price="B")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   90252      True  1.12293  1.12744  1.11837
# 2020-07-01 21:00:00+00:00   90789      True  1.12501  1.13020  1.12188
# 2020-07-02 21:00:00+00:00   59036      True  1.12384  1.12492  1.12186
# 2020-07-05 21:00:00+00:00   81756      True  1.12423  1.13449  1.12391
# 2020-07-06 21:00:00+00:00   92426      True  1.13070  1.13318  1.12581
# 2020-07-07 21:00:00+00:00   89549      True  1.12717  1.13505  1.12615
# 2020-07-08 21:00:00+00:00  104729      True  1.13287  1.13699  1.12774
# 2020-07-09 21:00:00+00:00   81510      True  1.12808  1.13242  1.12540
# 2020-07-12 21:00:00+00:00   86512      True  1.13042  1.13744  1.13002
# 2020-07-13 21:00:00+00:00  106478      True  1.13420  1.14081  1.13232
# 2020-07-14 21:00:00+00:00  100308      True  1.13979  1.14512  1.13901
# 2020-07-15 21:00:00+00:00  102144      True  1.14108  1.14411  1.13698
# ...

# %%
df = api.get_history(instrument= "EUR_USD", start = "2020-07-01", end = "2020-07-31", granularity= "D", price="B")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23 entries, 2020-06-30 21:00:00+00:00 to 2020-07-30 21:00:00+00:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   volume    23 non-null     int64
#  1   complete  23 non-null     bool
#  2   o         23 non-null     float64
#  3   h         23 non-null     float64
#  4   l         23 non-null     float64
#  5   c         23 non-null     float64
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 1.1 KB

# %%
api.get_history(instrument= "EUR_USD", start = "2020-07-01", end = "2020-07-01", granularity= "D", price="A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   90252      True  1.12393  1.12758  1.11858
#
#                                  c
# time
# 2020-06-30 21:00:00+00:00  1.12527

# %%
api.get_history(instrument= "EUR_USD", start = "2020-07-01", end = "2020-07-01", granularity= "D", price="B")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2020-06-30 21:00:00+00:00   90252      True  1.12293  1.12744  1.11837
#
#                                  c
# time
# 2020-06-30 21:00:00+00:00  1.12501

# %%
api.get_history("EUR_USD", "2021-11-04", "2021-11-05", "H1", "A")
# Out:
#                            volume  complete        o        h        l  \
# time
# 2021-11-04 00:00:00+00:00     978      True  1.16161  1.16170  1.16122
# 2021-11-04 01:00:00+00:00    1090      True  1.16134  1.16135  1.16039
# 2021-11-04 02:00:00+00:00     787      True  1.16048  1.16076  1.16010
# 2021-11-04 03:00:00+00:00     753      True  1.16056  1.16062  1.15935
# 2021-11-04 04:00:00+00:00     791      True  1.15942  1.15966  1.15916
# 2021-11-04 05:00:00+00:00    1029      True  1.15914  1.15928  1.15862
# 2021-11-04 06:00:00+00:00    2605      True  1.15896  1.15896  1.15785
# 2021-11-04 07:00:00+00:00    3717      True  1.15787  1.15829  1.15706
# 2021-11-04 08:00:00+00:00    7397      True  1.15721  1.15725  1.15497
# 2021-11-04 09:00:00+00:00    4060      True  1.15538  1.15557  1.15482
# 2021-11-04 10:00:00+00:00    3649      True  1.15535  1.15535  1.15434
# 2021-11-04 11:00:00+00:00    4324      True  1.15463  1.15554  1.15451
# ...

# %%
api.stream_data('EUR_USD')
api.stop_stream()
# Out:
# 2021-11-08T15:14:16.103972803Z 1.15854 1.15868
# 2021-11-08T15:14:16.280175546Z 1.15854 1.15866
# 2021-11-08T15:14:16.701327675Z 1.15854 1.15868
# 2021-11-08T15:14:16.888870370Z 1.15853 1.15867
# 2021-11-08T15:14:17.702707258Z 1.15853 1.15869
# 2021-11-08T15:14:17.780981581Z 1.15855 1.15872
# 2021-11-08T15:14:18.274353770Z 1.15854 1.15868
# 2021-11-08T15:14:18.897530048Z 1.15855 1.15869
# 2021-11-08T15:14:19.459273643Z 1.15854 1.15868
# 2021-11-08T15:14:19.585001698Z 1.15858 1.15872
# 2021-11-08T15:14:21.700026737Z 1.1586 1.15875
# 2021-11-08T15:14:22.689649539Z 1.15867 1.15882
# 2021-11-08T15:14:22.739299608Z 1.15864 1.15878
# 2021-11-08T15:14:23.489399586Z 1.15866 1.1588
# 2021-11-08T15:14:24.208760969Z 1.15862 1.15876
# 2021-11-08T15:14:26.465298336Z 1.1586 1.15873
# 2021-11-08T15:14:26.505586296Z 1.15863 1.15876
# 2021-11-08T15:14:27.326549142Z 1.1586 1.15876
# 2021-11-08T15:14:28.688686785Z 1.15864 1.15878
# 2021-11-08T15:14:29.201582988Z 1.15867 1.15881
# ...

# %%
api.create_order(instrument= "EUR_USD", units = 100000, sl_distance= 0.1)
# Out:
#  {'id': '5', 'time': '2021-11-08T15:15:37.837177478Z', 'userID': 20947775, 'accountID': '101-001-20947775-001', 'batchID': '4', 'requestID': '78921088249350660', 'type': 'ORDER_FILL', 'orderID': '4', 'instrument': 'EUR_USD', 'units': '100000.0', 'gainQuoteHomeConversionFactor': '1.0', 'lossQuoteHomeConversionFactor': '1.0', 'price': 1.15848, 'fullVWAP': 1.15848, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 1.15834, 'liquidity': '10000000'}], 'asks': [{'price': 1.15848, 'liquidity': '10000000'}], 'closeoutBid': 1.15834, 'closeoutAsk': 1.15848}, 'reason': 'MARKET_ORDER', 'pl': '0.0', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '100000.0', 'tradeOpened': {'tradeID': '5', 'units': '100000.0', 'price': 1.15848, 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '7.0', 'initialMarginRequired': '2316.82'}, 'halfSpreadCost': '7.0'}
